# %% [markdown]
# ### **Importing useful library**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Loading Accident dataset**

# %%
data = pd.read_csv(r'C:\Users\ZAFAR ANSARI\Downloads\accident.csv')
data
# Out:
#     Accident_ID           State        Date      Time                Reason  \
# 0          1001  Andhra Pradesh  2021-05-01  15:30:00              Speeding
# 1          1002       Karnataka  2021-05-02  18:45:00         Drunk Driving
# 2          1003           Delhi  2021-05-03  10:15:00  Poor Road Conditions
# 3          1004     Maharashtra  2021-05-04  06:00:00        Driver Fatigue
# 4          1005   Uttar Pradesh  2021-05-05  21:20:00              Speeding
# ..          ...             ...         ...       ...                   ...
# 295        1296          Odisha  2022-04-16  16:30:00  Poor road conditions
# 296        1297       Karnataka  2022-04-17  08:50:00              Speeding
# 297        1298  Andhra Pradesh  2022-04-18  03:00:00        Driver fatigue
# 298        1299       Telangana  2022-04-19  20:10:00              Speeding
# 299        1300          Kerala  2022-04-20  11:45:00         Drunk driving
#
# ...

# %%
print(data.columns)
# Out:
# Index(['Accident_ID', 'State', 'Date', 'Time', 'Reason', 'Number_of_Deaths',
#        'Number_of_Injuries', 'Road_Type', 'Weather_Conditions',
#        'Alcohol_Involved', 'Driver_Fatigue', 'Road_Conditions', 'Speed_Limit'],
#       dtype='object')

# %%
data.drop('Accident_ID', axis=1, inplace=True)
data.drop('Date', axis=1, inplace=True)
data.drop('Time', axis=1, inplace=True)
data.drop('Road_Type', axis=1, inplace=True)
data.drop('Weather_Conditions', axis=1, inplace=True)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               300 non-null    object
#  1   Reason              300 non-null    object
#  2   Number_of_Deaths    300 non-null    int64
#  3   Number_of_Injuries  300 non-null    object
#  4   Alcohol_Involved    300 non-null    object
#  5   Driver_Fatigue      300 non-null    object
#  6   Road_Conditions     300 non-null    object
#  7   Speed_Limit         299 non-null    float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 18.9+ KB
# None

# %%
data.describe()
# Out:
#        Number_of_Deaths  Speed_Limit
# count        300.000000   299.000000
# mean           1.766667    56.989967
# std            1.090651    13.042390
# min            0.000000    30.000000
# 25%            1.000000    50.000000
# 50%            2.000000    60.000000
# 75%            3.000000    60.000000
# max            5.000000    90.000000

# %%
data.describe(include=["object", "bool"])
# Out:
#               State    Reason Number_of_Injuries Alcohol_Involved  \
# count           300       300                300              300
# unique           28         8                  8                2
# top     Maharashtra  Speeding                  2               No
# freq             29        84                 93              200
#
#        Driver_Fatigue Road_Conditions
# count             300             300
# unique              3               4
# top                No            Good
# freq              214             112

# %%
data["State"].value_counts()
# Out:
# State
# Maharashtra         29
# Karnataka           26
# Andhra Pradesh      25
# Tamil Nadu          23
# West Bengal         20
# Gujarat             19
# Assam               18
# Odisha              15
# Kerala              15
# Delhi               13
# Rajasthan           13
# Punjab              13
# Madhya Pradesh      12
# Uttar Pradesh       12
# Chhattisgarh         9
# Haryana              8
# Jharkhand            6
# Telangana            6
# Bihar                4
# Manipur              4
# Uttarakhand          2
# Goa                  2
# Himachal Pradesh     1
# Meghalaya            1
# Mizoram              1
# Nagaland             1
# Sikkim               1
# 2022-09-20           1
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# State                 0
# Reason                0
# Number_of_Deaths      0
# Number_of_Injuries    0
# Alcohol_Involved      0
# Driver_Fatigue        0
# Road_Conditions       0
# Speed_Limit           1
# dtype: int64

# %%
data["Speed_Limit"].fillna(data["Speed_Limit"].mean(),inplace=True)
# Out:
# C:\Users\ZAFAR ANSARI\AppData\Local\Temp\ipykernel_32432\3745347939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Speed_Limit"].fillna(data["Speed_Limit"].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# State                 0
# Reason                0
# Number_of_Deaths      0
# Number_of_Injuries    0
# Alcohol_Involved      0
# Driver_Fatigue        0
# Road_Conditions       0
# Speed_Limit           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 23

# %%
data["Speed_Limit"].mean()
# Out:
# 56.989966555183955

# %%
data["Number_of_Deaths"].mean()
# Out:
# 1.7666666666666666

# %%
data["Number_of_Deaths"].median()
# Out:
# 2.0

# %%
data["Number_of_Deaths"].mode()
# Out:
# 0    1
# Name: Number_of_Deaths, dtype: int64

# %%
sns.histplot(x='Number_of_Deaths' , data=data, )
plt.title('Number_of_Deaths_in_Accident')
plt.ylabel('Count')
plt.xlabel('Number_of_Deaths')
plt.show()

# %%
sns.countplot(x='Alcohol_Involved', data=data,palette='deep')
plt.title('Alcohol_Involved or not')
plt.ylabel('number_of_Accident')
plt.xlabel('Alcohol_Involved')
plt.show()
# Out:
# C:\Users\ZAFAR ANSARI\AppData\Local\Temp\ipykernel_32432\2257587760.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Alcohol_Involved', data=data,palette='deep')

# %%
rc_counts = data['Road_Conditions'].value_counts()

# Plot
plt.figure(figsize=(6, 6))  # 🔹 Figure size adjust kiya
plt.pie(rc_counts, labels=rc_counts.index, autopct='%1.1f%%', 
        colors=plt.cm.Paired.colors, startangle=90)

# Title change kiya
plt.title('Road_Conditions', fontsize=14, fontweight='bold')

# Show plot
plt.show()

# %%
values = data["Reason"].value_counts().iloc[:10]
plt.figure(figsize=(10, 6))
sns.barplot(x=values.index, y=values.values, hue=values.index, dodge=False, palette="viridis", legend=False)
plt.xlabel("Reason")
plt.ylabel("number_of_Accident")
plt.title("Top Most Common Reason")
plt.xticks(rotation=45)
plt.show()

# %%
values = data["State"].value_counts().iloc[:10]
plt.figure(figsize=(10, 6))
sns.barplot(x=values.index, y=values.values, hue=values.index, dodge=False, palette="cool", legend=False)
plt.xlabel("State")
plt.ylabel("number_of_Accident")
plt.title("Top 10 Most Common State")
plt.xticks(rotation=45)
plt.show()
